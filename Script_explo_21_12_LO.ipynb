# %% [markdown]
# Aim of this notebook:
# -exploring datasets of socio demographic informations

# %%
#Importer les packages 
import pandas as pd
from pathlib import Path

# %%
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 3
#       1 from pathlib import Path
#       2 Path.cwd()
# ----> 3 set.cwd("c:/Users/user/Documents/Municipales_2026")
#
# AttributeError: type object 'set' has no attribute 'cwd'

# %%
#indiquer le répertoire des données
#donnees="C:/Users/user\Documents\Municipales_2026\Données"
#lire les données
#age 
#age=pd.read_csv("C:/Users/user/Documents/Municipales_2026/Données/Age_csp/Age_csp/agesexcommunes.csv")
#age=pd.read_csv(Path("Données/Age_csp/Age_csp/agesexcommunes.csv"))
age = pd.read_csv(
    Path("..") / "Données" / "Age_csp" / "Age_csp" / "agesexcommunes.csv"
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5312\252573482.py:7: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   age = pd.read_csv(

# %%
age
# Out:
#       dep           nomdep codecommune              nomcommune  poph0141962  \
# 0      25            DOUBS       25443               PALANTINE          5.0
# 1      70      HAUTE-SAONE       70440               RECOLOGNE          3.0
# 2      21        COTE-D'OR       21276   FONTAINES-EN-DUESMOIS         32.0
# 3      31    HAUTE-GARONNE       31266                  LAHAGE          6.0
# 4       6  ALPES-MARITIMES        6076                 LIEUCHE          1.0
# ...    ..              ...         ...                     ...          ...
# 37980  23           CREUSE       23231  SAINT-PIERRE-DE-FURSAC         85.0
# 37981  52      HAUTE-MARNE       52238              HARRICOURT          8.0
# 37982  48           LOZERE       48049                  CHIRAC         84.0
# 37983  61             ORNE       61205                  HEUGON         50.0
# 37984  14         CALVADOS       14470        NORREY-EN-BESSIN         32.0
#
#        poph15391962  poph40591962  poph60p1962  popf0141962  popf15391962  \
# 0               5.0           6.0          3.0          7.0           6.0
# 1               6.0           4.0          2.0          3.0           5.0
# 2              37.0          24.0         16.0         29.0          22.0
# 3              94.0          17.0         10.0          8.0          14.0
# 4               3.0           4.0          2.0          2.0           5.0
# ...             ...           ...          ...          ...           ...
# 37980         155.0         131.0        124.0        102.0         133.0
# 37981          13.0          10.0          8.0          8.0          10.0
# 37982         123.0          79.0         68.0        142.0         112.0
# 37983          54.0          45.0         33.0         60.0          57.0
# 37984          37.0          21.0         11.0         31.0          25.0
#
#        ...  perprop0141957  perprop60p1957  perpropf1958  perage1958  \
# 0      ...        0.929899        0.093060      0.946069    0.006167
# 1      ...        0.355285        0.711124      0.112636    0.088098
# 2      ...        0.938310        0.188820      0.043178    0.144777
# 3      ...        0.003273        0.089764      0.001752    0.149059
# 4      ...        0.069635        0.323348      0.509821    0.861277
# ...    ...             ...             ...           ...         ...
# 37980  ...        0.085405        0.952224      0.734750    0.980018
# 37981  ...        0.147660        0.659091      0.464339    0.898641
# 37982  ...        0.783682        0.893864      0.973157    0.652919
# 37983  ...        0.833193        0.591287      0.493604    0.358725
# 37984  ...        0.718533        0.267685      0.743903    0.446151
#
#        perprop0141958  perprop60p1958  perpropf1959  perage1959  \
# 0            0.929899        0.093060      0.946069    0.006167
# 1            0.355285        0.711124      0.112636    0.088098
# 2            0.938310        0.188820      0.043178    0.144777
# 3            0.003273        0.089764      0.001752    0.149059
# 4            0.069635        0.323348      0.509821    0.861277
# ...               ...             ...           ...         ...
# 37980        0.085405        0.952224      0.734750    0.980018
# 37981        0.147660        0.659091      0.464339    0.898641
# 37982        0.783682        0.893864      0.973157    0.652919
# 37983        0.833193        0.591287      0.493604    0.358725
# 37984        0.718533        0.267685      0.743903    0.446151
#
#        perprop0141959  perprop60p1959
# 0            0.929899        0.093060
# 1            0.355285        0.711124
# 2            0.938310        0.188820
# 3            0.003273        0.089764
# 4            0.069635        0.323348
# ...               ...             ...
# 37980        0.085405        0.952224
# 37981        0.147660        0.659091
# 37982        0.783682        0.893864
# 37983        0.833193        0.591287
# 37984        0.718533        0.267685
#
# [37985 rows x 2385 columns]

# %%
list(age.columns)
# Out:
# ['dep',
#  'nomdep',
#  'codecommune',
#  'nomcommune',
#  'poph0141962',
#  'poph15391962',
#  'poph40591962',
#  'poph60p1962',
#  'popf0141962',
#  'popf15391962',
#  'popf40591962',
#  'popf60p1962',
#  'ageh1962',
#  'agef1962',
#  'poph0141968',
#  'popf0141968',
#  'poph15391968',
#  'popf15391968',
#  'poph40591968',
#  'popf40591968',
#  'poph60p1968',
#  'popf60p1968',
#  'ageh1968',
#  'agef1968',
#  'poph0141975',
#  'popf0141975',
#  'poph15391975',
#  'popf15391975',
#  'poph40591975',
#  'popf40591975',
#  'poph60p1975',
#  'popf60p1975',
#  'ageh1975',
#  'agef1975',
#  'poph0141982',
#  'popf0141982',
#  'poph15391982',
#  'popf15391982',
#  'poph40591982',
#  'popf40591982',
#  'poph60p1982',
#  'popf60p1982',
#  'ageh1982',
#  'agef1982',
#  'poph0141990',
#  'popf0141990',
#  'poph15391990',
#  'popf15391990',
#  'poph40591990',
#  'popf40591990',
#  'poph60p1990',
#  'popf60p1990',
#  'ageh1990',
#  'agef1990',
#  'poph0141999',
#  'popf0141999',
#  'poph15391999',
#  'popf15391999',
#  'poph40591999',
#  'popf40591999',
#  'poph60p1999',
#  'popf60p1999',
#  'ageh1999',
#  'agef1999',
#  'poph0142006',
#  'popf0142006',
#  'poph15392006',
#  'popf15392006',
#  'poph40592006',
#  'popf40592006',
#  'poph60p2006',
#  'popf60p2006',
#  'ageh2006',
#  'agef2006',
#  'poph0142011',
#  'popf0142011',
#  'poph15392011',
#  'popf15392011',
#  'poph40592011',
#  'popf40592011',
#  'poph60p2011',
#  'popf60p2011',
#  'ageh2011',
#  'agef2011',
#  'poph0142016',
#  'popf0142016',
#  'poph15392016',
#  'popf15392016',
#  'poph40592016',
#  'popf40592016',
#  'poph60p2016',
#  'popf60p2016',
#  'ageh2016',
#  'agef2016',
#  'popf0141960',
#  'popf0141961',
#  'popf0141963',
#  'popf0141964',
#  'popf0141965',
#  'popf0141966',
#  'popf0141967',
#  'popf0141969',
#  'popf0141970',
#  'popf0141971',
#  'popf0141972',
#  'popf0141973',
#  'popf0141974',
#  'popf0141976',
#  'popf0141977',
#  'popf0141978',
#  'popf0141979',
#  'popf0141980',
#  'popf0141981',
#  'popf0141983',
#  'popf0141984',
#  'popf0141985',
#  'popf0141986',
#  'popf0141987',
#  'popf0141988',
#  'popf0141989',
#  'popf0141991',
#  'popf0141992',
#  'popf0141993',
#  'popf0141994',
#  'popf0141995',
#  'popf0141996',
#  'popf0141997',
#  'popf0141998',
#  'popf0142000',
#  'popf0142001',
#  'popf0142002',
#  'popf0142003',
#  'popf0142004',
#  'popf0142005',
#  'popf0142007',
#  'popf0142008',
#  'popf0142009',
#  'popf0142010',
#  'popf0142012',
#  'popf0142013',
#  'popf0142014',
#  'popf0142015',
#  'popf0142017',
#  'popf0142018',
#  'popf0142019',
#  'popf0142020',
#  'popf0142021',
#  'popf0142022',
#  'popf15391960',
#  'popf15391961',
#  'popf15391963',
#  'popf15391964',
#  'popf15391965',
#  'popf15391966',
#  'popf15391967',
#  'popf15391969',
#  'popf15391970',
#  'popf15391971',
#  'popf15391972',
#  'popf15391973',
#  'popf15391974',
#  'popf15391976',
#  'popf15391977',
#  'popf15391978',
#  'popf15391979',
#  'popf15391980',
#  'popf15391981',
#  'popf15391983',
#  'popf15391984',
#  'popf15391985',
#  'popf15391986',
#  'popf15391987',
#  'popf15391988',
#  'popf15391989',
#  'popf15391991',
#  'popf15391992',
#  'popf15391993',
#  'popf15391994',
#  'popf15391995',
#  'popf15391996',
#  'popf15391997',
#  'popf15391998',
#  'popf15392000',
#  'popf15392001',
#  'popf15392002',
#  'popf15392003',
#  'popf15392004',
#  'popf15392005',
#  'popf15392007',
#  'popf15392008',
#  'popf15392009',
#  'popf15392010',
#  'popf15392012',
#  'popf15392013',
#  'popf15392014',
#  'popf15392015',
#  'popf15392017',
#  'popf15392018',
#  'popf15392019',
#  'popf15392020',
#  'popf15392021',
#  'popf15392022',
#  'popf40591960',
#  'popf40591961',
#  'popf40591963',
#  'popf40591964',
#  'popf40591965',
#  'popf40591966',
#  'popf40591967',
#  'popf40591969',
#  'popf40591970',
#  'popf40591971',
#  'popf40591972',
#  'popf40591973',
#  'popf40591974',
#  'popf40591976',
#  'popf40591977',
#  'popf40591978',
#  'popf40591979',
#  'popf40591980',
#  'popf40591981',
#  'popf40591983',
#  'popf40591984',
#  'popf40591985',
#  'popf40591986',
#  'popf40591987',
#  'popf40591988',
#  'popf40591989',
#  'popf40591991',
#  'popf40591992',
#  'popf40591993',
#  'popf40591994',
#  'popf40591995',
#  'popf40591996',
#  'popf40591997',
#  'popf40591998',
#  'popf40592000',
#  'popf40592001',
#  'popf40592002',
#  'popf40592003',
#  'popf40592004',
#  'popf40592005',
#  'popf40592007',
#  'popf40592008',
#  'popf40592009',
#  'popf40592010',
#  'popf40592012',
#  'popf40592013',
#  'popf40592014',
#  'popf40592015',
#  'popf40592017',
#  'popf40592018',
#  'popf40592019',
#  'popf40592020',
#  'popf40592021',
#  'popf40592022',
#  'popf60p1960',
#  'popf60p1961',
#  'popf60p1963',
#  'popf60p1964',
#  'popf60p1965',
#  'popf60p1966',
#  'popf60p1967',
#  'popf60p1969',
#  'popf60p1970',
#  'popf60p1971',
#  'popf60p1972',
#  'popf60p1973',
#  'popf60p1974',
#  'popf60p1976',
#  'popf60p1977',
#  'popf60p1978',
#  'popf60p1979',
#  'popf60p1980',
#  'popf60p1981',
#  'popf60p1983',
#  'popf60p1984',
#  'popf60p1985',
#  'popf60p1986',
#  'popf60p1987',
#  'popf60p1988',
#  'popf60p1989',
#  'popf60p1991',
#  'popf60p1992',
#  'popf60p1993',
#  'popf60p1994',
#  'popf60p1995',
#  'popf60p1996',
#  'popf60p1997',
#  'popf60p1998',
#  'popf60p2000',
#  'popf60p2001',
#  'popf60p2002',
#  'popf60p2003',
#  'popf60p2004',
#  'popf60p2005',
#  'popf60p2007',
#  'popf60p2008',
#  'popf60p2009',
#  'popf60p2010',
#  'popf60p2012',
#  'popf60p2013',
#  'popf60p2014',
#  'popf60p2015',
#  'popf60p2017',
#  'popf60p2018',
#  'popf60p2019',
#  'popf60p2020',
#  'popf60p2021',
#  'popf60p2022',
#  'poph0141960',
#  'poph0141961',
#  'poph0141963',
#  'poph0141964',
#  'poph0141965',
#  'poph0141966',
#  'poph0141967',
#  'poph0141969',
#  'poph0141970',
#  'poph0141971',
#  'poph0141972',
#  'poph0141973',
#  'poph0141974',
#  'poph0141976',
#  'poph0141977',
#  'poph0141978',
#  'poph0141979',
#  'poph0141980',
#  'poph0141981',
#  'poph0141983',
#  'poph0141984',
#  'poph0141985',
#  'poph0141986',
#  'poph0141987',
#  'poph0141988',
#  'poph0141989',
#  'poph0141991',
#  'poph0141992',
#  'poph0141993',
#  'poph0141994',
#  'poph0141995',
#  'poph0141996',
#  'poph0141997',
#  'poph0141998',
#  'poph0142000',
#  'poph0142001',
#  'poph0142002',
#  'poph0142003',
#  'poph0142004',
#  'poph0142005',
#  'poph0142007',
#  'poph0142008',
#  'poph0142009',
#  'poph0142010',
#  'poph0142012',
#  'poph0142013',
#  'poph0142014',
#  'poph0142015',
#  'poph0142017',
#  'poph0142018',
#  'poph0142019',
#  'poph0142020',
#  'poph0142021',
#  'poph0142022',
#  'poph15391960',
#  'poph15391961',
#  'poph15391963',
#  'poph15391964',
#  'poph15391965',
#  'poph15391966',
#  'poph15391967',
#  'poph15391969',
#  'poph15391970',
#  'poph15391971',
#  'poph15391972',
#  'poph15391973',
#  'poph15391974',
#  'poph15391976',
#  'poph15391977',
#  'poph15391978',
#  'poph15391979',
#  'poph15391980',
#  'poph15391981',
#  'poph15391983',
#  'poph15391984',
#  'poph15391985',
#  'poph15391986',
#  'poph15391987',
#  'poph15391988',
#  'poph15391989',
#  'poph15391991',
#  'poph15391992',
#  'poph15391993',
#  'poph15391994',
#  'poph15391995',
#  'poph15391996',
#  'poph15391997',
#  'poph15391998',
#  'poph15392000',
#  'poph15392001',
#  'poph15392002',
#  'poph15392003',
#  'poph15392004',
#  'poph15392005',
#  'poph15392007',
#  'poph15392008',
#  'poph15392009',
#  'poph15392010',
#  'poph15392012',
#  'poph15392013',
#  'poph15392014',
#  'poph15392015',
#  'poph15392017',
#  'poph15392018',
#  'poph15392019',
#  'poph15392020',
#  'poph15392021',
#  'poph15392022',
#  'poph40591960',
#  'poph40591961',
#  'poph40591963',
#  'poph40591964',
#  'poph40591965',
#  'poph40591966',
#  'poph40591967',
#  'poph40591969',
#  'poph40591970',
#  'poph40591971',
#  'poph40591972',
#  'poph40591973',
#  'poph40591974',
#  'poph40591976',
#  'poph40591977',
#  'poph40591978',
#  'poph40591979',
#  'poph40591980',
#  'poph40591981',
#  'poph40591983',
#  'poph40591984',
#  'poph40591985',
#  'poph40591986',
#  'poph40591987',
#  'poph40591988',
#  'poph40591989',
#  'poph40591991',
#  'poph40591992',
#  'poph40591993',
#  'poph40591994',
#  'poph40591995',
#  'poph40591996',
#  'poph40591997',
#  'poph40591998',
#  'poph40592000',
#  'poph40592001',
#  'poph40592002',
#  'poph40592003',
#  'poph40592004',
#  'poph40592005',
#  'poph40592007',
#  'poph40592008',
#  'poph40592009',
#  'poph40592010',
#  'poph40592012',
#  'poph40592013',
#  'poph40592014',
#  'poph40592015',
#  'poph40592017',
#  'poph40592018',
#  'poph40592019',
#  'poph40592020',
#  'poph40592021',
#  'poph40592022',
#  'poph60p1960',
#  'poph60p1961',
#  'poph60p1963',
#  'poph60p1964',
#  'poph60p1965',
#  'poph60p1966',
#  'poph60p1967',
#  'poph60p1969',
#  'poph60p1970',
#  'poph60p1971',
#  'poph60p1972',
#  'poph60p1973',
#  'poph60p1974',
#  'poph60p1976',
#  'poph60p1977',
#  'poph60p1978',
#  'poph60p1979',
#  'poph60p1980',
#  'poph60p1981',
#  'poph60p1983',
#  'poph60p1984',
#  'poph60p1985',
#  'poph60p1986',
#  'poph60p1987',
#  'poph60p1988',
#  'poph60p1989',
#  'poph60p1991',
#  'poph60p1992',
#  'poph60p1993',
#  'poph60p1994',
#  'poph60p1995',
#  'poph60p1996',
#  'poph60p1997',
#  'poph60p1998',
#  'poph60p2000',
#  'poph60p2001',
#  'poph60p2002',
#  'poph60p2003',
#  'poph60p2004',
#  'poph60p2005',
#  'poph60p2007',
#  'poph60p2008',
#  'poph60p2009',
#  'poph60p2010',
#  'poph60p2012',
#  'poph60p2013',
#  'poph60p2014',
#  'poph60p2015',
#  'poph60p2017',
#  'poph60p2018',
#  'poph60p2019',
#  'poph60p2020',
#  'poph60p2021',
#  'poph60p2022',
#  'agef1960',
#  'ageh1960',
#  'agef1961',
#  'ageh1961',
#  'agef1963',
#  'ageh1963',
#  'agef1964',
#  'ageh1964',
#  'agef1965',
#  'ageh1965',
#  'agef1966',
#  'ageh1966',
#  'agef1967',
#  'ageh1967',
#  'agef1969',
#  'ageh1969',
#  'agef1970',
#  'ageh1970',
#  'agef1971',
#  'ageh1971',
#  'agef1972',
#  'ageh1972',
#  'agef1973',
#  'ageh1973',
#  'agef1974',
#  'ageh1974',
#  'agef1976',
#  'ageh1976',
#  'agef1977',
#  'ageh1977',
#  'agef1978',
#  'ageh1978',
#  'agef1979',
#  'ageh1979',
#  'agef1980',
#  'ageh1980',
#  'agef1981',
#  'ageh1981',
#  'agef1983',
#  'ageh1983',
#  'agef1984',
#  'ageh1984',
#  'agef1985',
#  'ageh1985',
#  'agef1986',
#  'ageh1986',
#  'agef1987',
#  'ageh1987',
#  'agef1988',
#  'ageh1988',
#  'agef1989',
#  'ageh1989',
#  'agef1991',
#  'ageh1991',
#  'agef1992',
#  'ageh1992',
#  'agef1993',
#  'ageh1993',
#  'agef1994',
#  'ageh1994',
#  'agef1995',
#  'ageh1995',
#  'agef1996',
#  'ageh1996',
#  'agef1997',
#  'ageh1997',
#  'agef1998',
#  'ageh1998',
#  'agef2000',
#  'ageh2000',
#  'agef2001',
#  'ageh2001',
#  'agef2002',
#  'ageh2002',
#  'agef2003',
#  'ageh2003',
#  'agef2004',
#  'ageh2004',
#  'agef2005',
#  'ageh2005',
#  'agef2007',
#  'ageh2007',
#  'agef2008',
#  'ageh2008',
#  'agef2009',
#  'ageh2009',
#  'agef2010',
#  'ageh2010',
#  'agef2012',
#  'ageh2012',
#  'agef2013',
#  'ageh2013',
#  'agef2014',
#  'ageh2014',
#  'agef2015',
#  'ageh2015',
#  'agef2017',
#  'ageh2017',
#  'agef2018',
#  'ageh2018',
#  'agef2019',
#  'ageh2019',
#  'agef2020',
#  'ageh2020',
#  'agef2021',
#  'ageh2021',
#  'agef2022',
#  'ageh2022',
#  'popf1960',
#  'poph1960',
#  'propf1960',
#  'age1960',
#  'pop1960',
#  'propf0141960',
#  'propf15391960',
#  'propf40591960',
#  'propf60p1960',
#  'prop0141960',
#  'prop15391960',
#  'prop40591960',
#  'prop60p1960',
#  'popf1961',
#  'poph1961',
#  'propf1961',
#  'age1961',
#  'pop1961',
#  'propf0141961',
#  'propf15391961',
#  'propf40591961',
#  'propf60p1961',
#  'prop0141961',
#  'prop15391961',
#  'prop40591961',
#  'prop60p1961',
#  'popf1962',
#  'poph1962',
#  'propf1962',
#  'age1962',
#  'pop1962',
#  'propf0141962',
#  'propf15391962',
#  'propf40591962',
#  'propf60p1962',
#  'prop0141962',
#  'prop15391962',
#  'prop40591962',
#  'prop60p1962',
#  'popf1963',
#  'poph1963',
#  'propf1963',
#  'age1963',
#  'pop1963',
#  'propf0141963',
#  'propf15391963',
#  'propf40591963',
#  'propf60p1963',
#  'prop0141963',
#  'prop15391963',
#  'prop40591963',
#  'prop60p1963',
#  'popf1964',
#  'poph1964',
#  'propf1964',
#  'age1964',
#  'pop1964',
#  'propf0141964',
#  'propf15391964',
#  'propf40591964',
#  'propf60p1964',
#  'prop0141964',
#  'prop15391964',
#  'prop40591964',
#  'prop60p1964',
#  'popf1965',
#  'poph1965',
#  'propf1965',
#  'age1965',
#  'pop1965',
#  'propf0141965',
#  'propf15391965',
#  'propf40591965',
#  'propf60p1965',
#  'prop0141965',
#  'prop15391965',
#  'prop40591965',
#  'prop60p1965',
#  'popf1966',
#  'poph1966',
#  'propf1966',
#  'age1966',
#  'pop1966',
#  'propf0141966',
#  'propf15391966',
#  'propf40591966',
#  'propf60p1966',
#  'prop0141966',
#  'prop15391966',
#  'prop40591966',
#  'prop60p1966',
#  'popf1967',
#  'poph1967',
#  'propf1967',
#  'age1967',
#  'pop1967',
#  'propf0141967',
#  'propf15391967',
#  'propf40591967',
#  'propf60p1967',
#  'prop0141967',
#  'prop15391967',
#  'prop40591967',
#  'prop60p1967',
#  'popf1968',
#  'poph1968',
#  'propf1968',
#  'age1968',
#  'pop1968',
#  'propf0141968',
#  'propf15391968',
#  'propf40591968',
#  'propf60p1968',
#  'prop0141968',
#  'prop15391968',
#  'prop40591968',
#  'prop60p1968',
#  'popf1969',
#  'poph1969',
#  'propf1969',
#  'age1969',
#  'pop1969',
#  'propf0141969',
#  'propf15391969',
#  'propf40591969',
#  'propf60p1969',
#  'prop0141969',
#  'prop15391969',
#  'prop40591969',
#  'prop60p1969',
#  'popf1970',
#  'poph1970',
#  'propf1970',
#  'age1970',
#  'pop1970',
#  'propf0141970',
#  'propf15391970',
#  'propf40591970',
#  'propf60p1970',
#  'prop0141970',
#  'prop15391970',
#  'prop40591970',
#  'prop60p1970',
#  'popf1971',
#  'poph1971',
#  'propf1971',
#  'age1971',
#  'pop1971',
#  'propf0141971',
#  'propf15391971',
#  'propf40591971',
#  'propf60p1971',
#  'prop0141971',
#  'prop15391971',
#  'prop40591971',
#  'prop60p1971',
#  'popf1972',
#  'poph1972',
#  'propf1972',
#  'age1972',
#  'pop1972',
#  'propf0141972',
#  'propf15391972',
#  'propf40591972',
#  'propf60p1972',
#  'prop0141972',
#  'prop15391972',
#  'prop40591972',
#  'prop60p1972',
#  'popf1973',
#  'poph1973',
#  'propf1973',
#  'age1973',
#  'pop1973',
#  'propf0141973',
#  'propf15391973',
#  'propf40591973',
#  'propf60p1973',
#  'prop0141973',
#  'prop15391973',
#  'prop40591973',
#  'prop60p1973',
#  'popf1974',
#  'poph1974',
#  'propf1974',
#  'age1974',
#  'pop1974',
#  'propf0141974',
#  'propf15391974',
#  'propf40591974',
#  'propf60p1974',
#  'prop0141974',
#  'prop15391974',
#  'prop40591974',
#  'prop60p1974',
#  'popf1975',
#  'poph1975',
#  'propf1975',
#  'age1975',
#  'pop1975',
#  'propf0141975',
#  'propf15391975',
#  'propf40591975',
#  'propf60p1975',
#  'prop0141975',
#  'prop15391975',
#  'prop40591975',
#  'prop60p1975',
#  'popf1976',
#  'poph1976',
#  'propf1976',
#  'age1976',
#  'pop1976',
#  'propf0141976',
#  'propf15391976',
#  'propf40591976',
#  'propf60p1976',
#  'prop0141976',
#  'prop15391976',
#  'prop40591976',
#  'prop60p1976',
#  'popf1977',
#  'poph1977',
#  'propf1977',
#  'age1977',
#  'pop1977',
#  'propf0141977',
#  'propf15391977',
#  'propf40591977',
#  'propf60p1977',
#  'prop0141977',
#  'prop15391977',
#  'prop40591977',
#  'prop60p1977',
#  'popf1978',
#  'poph1978',
#  'propf1978',
#  'age1978',
#  'pop1978',
#  'propf0141978',
#  'propf15391978',
#  'propf40591978',
#  'propf60p1978',
#  'prop0141978',
#  'prop15391978',
#  'prop40591978',
#  'prop60p1978',
#  'popf1979',
#  'poph1979',
#  'propf1979',
#  'age1979',
#  'pop1979',
#  'propf0141979',
#  'propf15391979',
#  'propf40591979',
#  'propf60p1979',
#  'prop0141979',
#  'prop15391979',
#  'prop40591979',
#  'prop60p1979',
#  'popf1980',
#  'poph1980',
#  'propf1980',
#  'age1980',
#  'pop1980',
#  'propf0141980',
#  'propf15391980',
#  'propf40591980',
#  'propf60p1980',
#  'prop0141980',
#  'prop15391980',
#  'prop40591980',
#  'prop60p1980',
#  'popf1981',
#  'poph1981',
#  'propf1981',
#  'age1981',
#  'pop1981',
#  'propf0141981',
#  'propf15391981',
#  'propf40591981',
#  'propf60p1981',
#  'prop0141981',
#  'prop15391981',
#  'prop40591981',
#  'prop60p1981',
#  'popf1982',
#  'poph1982',
#  'propf1982',
#  'age1982',
#  'pop1982',
#  'propf0141982',
#  'propf15391982',
#  'propf40591982',
#  'propf60p1982',
#  'prop0141982',
#  'prop15391982',
#  'prop40591982',
#  'prop60p1982',
#  'popf1983',
#  'poph1983',
#  'propf1983',
#  'age1983',
#  'pop1983',
#  'propf0141983',
#  'propf15391983',
#  'propf40591983',
#  'propf60p1983',
#  'prop0141983',
#  'prop15391983',
#  'prop40591983',
#  'prop60p1983',
#  'popf1984',
#  'poph1984',
#  'propf1984',
#  'age1984',
#  'pop1984',
#  'propf0141984',
#  'propf15391984',
#  'propf40591984',
#  'propf60p1984',
#  'prop0141984',
#  'prop15391984',
#  'prop40591984',
#  'prop60p1984',
#  'popf1985',
#  'poph1985',
#  'propf1985',
#  'age1985',
#  'pop1985',
#  'propf0141985',
#  'propf15391985',
#  'propf40591985',
#  'propf60p1985',
#  'prop0141985',
#  'prop15391985',
#  'prop40591985',
#  'prop60p1985',
#  'popf1986',
#  'poph1986',
#  'propf1986',
#  'age1986',
#  'pop1986',
#  'propf0141986',
#  'propf15391986',
#  'propf40591986',
#  'propf60p1986',
#  'prop0141986',
#  'prop15391986',
#  'prop40591986',
#  'prop60p1986',
#  'popf1987',
#  'poph1987',
#  'propf1987',
#  'age1987',
#  'pop1987',
#  'propf0141987',
#  'propf15391987',
#  'propf40591987',
#  'propf60p1987',
#  'prop0141987',
#  'prop15391987',
#  'prop40591987',
#  'prop60p1987',
#  'popf1988',
#  'poph1988',
#  ...]

# %%
#regarder ce que sont ces colonnes (age+ date) 
age.ageh2022 #age moyen dans la commune ?? pas sûre
# Out:
# 0        18.000000
# 1        63.200001
# 2        44.736843
# 3        47.094112
# 4        45.500000
#            ...
# 37980    18.000000
# 37981    18.000000
# 37982    18.000000
# 37983    18.000000
# 37984    18.000000
# Name: ageh2022, Length: 37985, dtype: float64

# %% [markdown]
# noms :
# poph =pop homme
# popf= pop femme
#
# CCL :
# pour chaque année découpage pop H et F pour 0-14, 15-39, 40-59, 60 et +
# age moyen pour F H et Total ( pas sûr)
# perage + date ??????
#
# 37985 communes × 2385 variables
